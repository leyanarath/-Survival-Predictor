# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/train.csv',encoding='unicode_escape')

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           0       3    male  22.0      1      0         A/5 21171   7.2500
# 1           1       1  female  38.0      1      0          PC 17599  71.2833
# 2           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female  35.0      1      0            113803  53.1000
# 4           0       3    male  35.0      0      0            373450   8.0500
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536  13.0000
# 887         1       1  female  19.0      0      0            112053  30.0000
# 888         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 889         1       1    male  26.0      0      0            111369  30.0000
# 890         0       3    male  32.0      0      0            370376   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data=data.drop(['Cabin','PassengerId','Name'],axis=1)

# %%
temp1=data.groupby(['Embarked','Survived']).count().reset_index()
temp1
# Out:
#   Embarked  Survived  Pclass  Sex  Age  SibSp  Parch  Ticket  Fare
# 0        C         0      75   75   51     75     75      75    75
# 1        C         1      93   93   79     93     93      93    93
# 2        Q         0      47   47   20     47     47      47    47
# 3        Q         1      30   30    8     30     30      30    30
# 4        S         0     427  427  353    427    427     427   427
# 5        S         1     217  217  201    217    217     217   217

# %%
data=data.fillna(method='ffill')

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
data.describe()
# Out:
#          Survived      Pclass        Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.00000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.58156    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.55459    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.42000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.00000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.00000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.00000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.00000    8.000000    6.000000  512.329200

# %%
data[data['Age']>38]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch    Ticket     Fare Embarked
# 6           0       1    male  54.0      0      0     17463  51.8625        S
# 11          1       1  female  58.0      0      0    113783  26.5500        S
# 13          0       3    male  39.0      1      5    347082  31.2750        S
# 15          1       2  female  55.0      0      0    248706  16.0000        S
# 30          0       1    male  40.0      0      0  PC 17601  27.7208        C
# ..        ...     ...     ...   ...    ...    ...       ...      ...      ...
# 865         1       2  female  42.0      0      0    236852  13.0000        S
# 871         1       1  female  47.0      1      1     11751  52.5542        S
# 873         0       3    male  47.0      0      0    345765   9.0000        S
# 879         1       1  female  56.0      0      1     11767  83.1583        C
# 885         0       3  female  39.0      0      5    382652  29.1250        Q
#
# [221 rows x 9 columns]

# %%
data=data.drop(['Ticket'],axis=1)

# %%
dummies = pd.get_dummies(data)

# %%
dummies.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0         0       3  22.0      1      0   7.2500           0         1
# 1         1       1  38.0      1      0  71.2833           1         0
# 2         1       3  26.0      0      0   7.9250           1         0
# 3         1       1  35.0      1      0  53.1000           1         0
# 4         0       3  35.0      0      0   8.0500           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
y = dummies.Survived
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
X = dummies.drop('Survived', axis='columns')
X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  22.0      1      0   7.2500           0         1           0
# 1       1  38.0      1      0  71.2833           1         0           1
# 2       3  26.0      0      0   7.9250           1         0           0
# 3       1  35.0      1      0  53.1000           1         0           0
# 4       3  35.0      0      0   8.0500           0         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
lr_model = LogisticRegression()

# %%
lr_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.8156424581005587
